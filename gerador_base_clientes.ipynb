# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiobaroliveira/gerador_base_de_dados/blob/main/gerador_base_clientes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Necessário instalar a biblioteca faker
! pip install faker
# Out:
# Collecting faker
#   Downloading faker-37.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from faker) (2025.2)
# Downloading faker-37.1.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 20.7 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-37.1.0

# %%
import pandas as pd
from faker import Faker
import random
from datetime import datetime, timedelta
fake = Faker('pt_BR')

# %%
NUM_CLIENTES = 100  # Número de clientes

clientes = []
for i in range(1, NUM_CLIENTES + 1):
    sexo = random.choice(["Masculino", "Feminino"])
    nome = fake.first_name_male() if sexo == "Masculino" else fake.first_name_female()
    clientes.append({
        "id_cliente": i,
        "nome": f"{nome} {fake.last_name()}",
        "cpf": fake.cpf(),
        "telefone": fake.phone_number(),
        "email": fake.safe_email(),
        "data_nascimento": fake.date_of_birth(minimum_age=18, maximum_age=70),
        "sexo": sexo,
        "estado civil": random.choice(["Solteiro", "Casado", "Divorciado", "Viúvo"]),
        "endereco": fake.street_address(),
        "cidade": fake.city(),
        "estado": fake.state_abbr(),
        "cep": fake.postcode(),
        "empresa": fake.company(),
        "cargo": fake.job(),
        "renda_mensal": round(random.uniform(1000, 10000), 2)
    })

df_clientes = pd.DataFrame(clientes)
df_clientes.head()
# Out:
#    id_cliente                  nome             cpf          telefone  \
# 0           1    Luiz Gustavo Gomes  825.703.469-00  +55 51 0869 6396
# 1           2       Catarina Guerra  281.546.370-90      21 4439-0286
# 2           3         Isaque da Paz  239.106.758-59  +55 84 9450 8217
# 3           4         Lunna Marques  802.543.196-70   (041) 0127 7815
# 4           5  Vitor Gabriel Guerra  871.035.249-04      71 9053 8857
#
#                           email data_nascimento       sexo estado civil  \
# 0           vitor95@example.org      1976-12-26  Masculino       Casado
# 1         mirella78@example.org      1973-10-28   Feminino     Solteiro
# 2  montenegrooliver@example.org      1976-01-23  Masculino        Viúvo
# 3      araujomarina@example.com      1965-11-16   Feminino        Viúvo
# 4          alicia80@example.com      1967-07-18  Masculino       Casado
#
#               endereco                cidade estado        cep  \
# 0   Colônia de Azevedo                 Lopes     CE  59154-503
# 1   Viela de Porto, 51     Farias das Flores     CE  93670-652
# 2   Rua de da Mota, 45  Moreira dos Dourados     CE   38758139
# 3  Ladeira de da Costa     Carvalho de Pires     RS   61995618
# 4   Feira Nogueira, 20                Cirino     GO  66173-814
#
#                 empresa                   cargo  renda_mensal
# 0  Monteiro Mendes - EI          Técnico de som       8040.50
# 1        Sá Sales Ltda.  Administrador de redes       5544.04
# 2                Cirino        Chefe de cozinha       4957.39
# 3               Correia             Confeiteiro       5836.46
# 4                 Silva                 Regente       7140.96

# %%
from google.colab import files

# Cria arquivos .csv com o separador ;
df_clientes.to_csv('clientes.csv', index=False, sep=';')

# Faz o download dos arquivos
files.download('clientes.csv')
